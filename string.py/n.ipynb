# %%
import numpy as np

# %%
w=np.array([1,2,3,4]) #weight
y=np.array([0.1,0.3,0.4,0.5])#inputs
b=0.1

# %%
a=np.dot(w,y)+b

# %%
relu=max(0,a)
print("output",relu)
# Out:
# output 4.0

# %% [markdown]
# 12
# 12
# 12
# 2121
